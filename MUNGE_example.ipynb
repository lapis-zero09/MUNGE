# %%
from itertools import combinations
from matplotlib import pyplot as plt
from sklearn import datasets
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from scipy.io import arff

# %%
iris = datasets.load_iris()

scaler = MinMaxScaler()
features = scaler.fit_transform(iris.data)
feature_names = [name.split(' (')[0] for name in iris.feature_names]
targets = iris.target

# %%
np.save('./data/data.npy', features)

# %%
plt.figure(figsize=(12, 8))

for i, (x, y) in enumerate(combinations(range(4), 2)):
    plt.subplot(2, 3, i + 1)
    for t, marker, c in zip(range(3), '>ox', 'rgb'):
        plt.scatter(features[targets == t, x],
                    features[targets == t, y],
                    marker=marker, c=c, alpha=0.5)
        plt.xlabel(feature_names[x])
        plt.ylabel(feature_names[y])
        plt.autoscale()
        plt.grid()

plt.savefig("./img/iris.png", dpi=200)
plt.show()

# %%
dataset, meta = arff.loadarff('./data/munge_p_0.5s_10.0.arff')
dataset = np.asarray(dataset.tolist(), dtype=np.float32)[200:]
dataset
# Out:
# array([[ 0.72480899,  0.5       ,  0.66010499,  0.58358997],
#        [ 0.55681098,  0.54245299,  0.623447  ,  0.58333302],
#        [ 0.72469503,  0.49475199,  0.661017  ,  0.58357698],
#        ...,
#        [ 0.61111099,  0.41666701,  0.71186399,  0.79166698],
#        [ 0.52777803,  0.58333302,  0.745763  ,  0.914895  ],
#        [ 0.496452  ,  0.41666701,  0.66333598,  0.70833302]], dtype=float32)

# %%
plt.figure(figsize=(12, 8))

for i, (x, y) in enumerate(combinations(range(4), 2)):
    plt.subplot(2, 3, i + 1)
    for _ in range(3):
        plt.scatter(dataset[:, x], dataset[:, y], marker='.', c='r')
        plt.xlabel(feature_names[x])
        plt.ylabel(feature_names[y])
        plt.autoscale()
        plt.grid()

plt.savefig("./img/munge_p_0.5s_10.0.png", dpi=200)
plt.show()

# %%
dataset, meta = arff.loadarff('./data/munge_p_0.8s_100.0.arff')
dataset = np.asarray(dataset.tolist(), dtype=np.float32)[200:]
dataset
# Out:
# array([[ 0.72234702,  0.458296  ,  0.660496  ,  0.58267897],
#        [ 0.55574203,  0.54196298,  0.62683499,  0.62494701],
#        [ 0.72234702,  0.458296  ,  0.661017  ,  0.582681  ],
#        ...,
#        [ 0.61111099,  0.41666701,  0.71186399,  0.79166698],
#        [ 0.52777803,  0.58363003,  0.72882599,  0.91666698],
#        [ 0.47216699,  0.41620401,  0.64318001,  0.70833302]], dtype=float32)

# %%
plt.figure(figsize=(12, 8))

for i, (x, y) in enumerate(combinations(range(4), 2)):
    plt.subplot(2, 3, i + 1)
    for _ in range(3):
        plt.scatter(dataset[:, x], dataset[:, y], marker='.', c='r')
        plt.xlabel(feature_names[x])
        plt.ylabel(feature_names[y])
        plt.autoscale()
        plt.grid()

plt.savefig("./img/munge_p_0.8s_100.0.png", dpi=200)
plt.show()

# %%
dataset, meta = arff.loadarff('./data/munge_p_0.8s_10.0.arff')
dataset = np.asarray(dataset.tolist(), dtype=np.float32)[200:]
dataset.shape
# Out:
# (1000, 4)

# %%
plt.figure(figsize=(12, 8))

for i, (x, y) in enumerate(combinations(range(4), 2)):
    plt.subplot(2, 3, i + 1)
    for _ in range(3):
        plt.scatter(dataset[:, x], dataset[:, y], marker='.', c='r')
        plt.xlabel(feature_names[x])
        plt.ylabel(feature_names[y])
        plt.autoscale()
        plt.grid()
        
plt.savefig("./img/munge_p_0.8s_10.0.png", dpi=200)
plt.show()

# %%
dataset, meta = arff.loadarff('./data/munge_p_0.8s_1.0.arff')
dataset = np.asarray(dataset.tolist(), dtype=np.float32)[200:]
dataset.shape
# Out:
# (1000, 4)

# %%
plt.figure(figsize=(12, 8))

for i, (x, y) in enumerate(combinations(range(4), 2)):
    plt.subplot(2, 3, i + 1)
    for _ in range(3):
        plt.scatter(dataset[:, x], dataset[:, y], marker='.', c='r')
        plt.xlabel(feature_names[x])
        plt.ylabel(feature_names[y])
        plt.autoscale()
        plt.grid()

plt.savefig("./img/munge_p_0.8s_1.0.png", dpi=200)
plt.show()

# %%
dataset, meta = arff.loadarff('./data/munge_p_0.8s_0.01.arff')
dataset = np.asarray(dataset.tolist(), dtype=np.float32)[200:]
dataset.shape
# Out:
# (1000, 4)

# %%
plt.figure(figsize=(12, 8))

for i, (x, y) in enumerate(combinations(range(4), 2)):
    plt.subplot(2, 3, i + 1)
    for _ in range(3):
        plt.scatter(dataset[:, x], dataset[:, y], marker='.', c='r')
        plt.xlabel(feature_names[x])
        plt.ylabel(feature_names[y])
        plt.autoscale()
        plt.grid()

plt.savefig("./img/munge_p_0.8s_0.01.png", dpi=200)
plt.show()
